# %% [markdown]
# # Brute force db migration

# %%
# %load_ext autoreload 
# %autoreload 2
import sqlite3 
from sqlite3 import Error 
import sql_tools
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path_hokui = "../../app_hokui.sqlite" # old version of file. 
path_hokumed = "./app.sqlite" # should be empty.

# %% [markdown]
# # User migration

# %%
sql_tools.user_migration()
# Out:
# sqlFetchCommand
# finish!
# insertCommand
# finish!

# %%
sql_tools.semester_migration()
# Out:
# sqlFetchCommand
# finish!
# insertCommand
# finish!

# %%
sql_tools.semesters_subjects_migration()
# Out:
# sqlFetchCommand
# finish!
# insertCommand
# finish!

# %%
sql_tools.subjects_migration()
# Out:
# sqlFetchCommand
# finish!
# insertCommand
# finish!

# %%
sql_tools.document_files_migration()
# Out:
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# finish!
# sqlFetchCommand
# ...

# %%
sql_tools.class_years_migration()
# Out:
# sqlFetchCommand
# finish!
# insertCommand
# finish!
